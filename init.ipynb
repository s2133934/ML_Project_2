# %%
# %%bash
# pip install --upgrade pip
#
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.7/site-packages (21.0.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/site-packages (from -r ./requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: scikit-learn>=0.24 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (0.24.1)
# Requirement already satisfied: seaborn>=0.11.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 4)) (0.11.1)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.7/site-packages (from -r ./requirements.txt (line 5)) (1.19.5)
# Collecting ipywidgets>=7.5.1
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: nbconvert>=5.6.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (6.0.7)
# Collecting datapackage>=1.15.2
#   Downloading datapackage-1.15.2-py2.py3-none-any.whl (85 kB)
# Collecting geopy>=2.1.0
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting dataprep>=0.2.15
#   Downloading dataprep-0.2.15-py3-none-any.whl (193 kB)
# Collecting ccy>=1.2.2
#   Downloading ccy-1.2.2-py37-none-any.whl (16 kB)
# Collecting pycountry==20.7.3
#   Downloading pycountry-20.7.3.tar.gz (10.1 MB)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ccy>=1.2.2->-r ./requirements.txt (line 11)) (2.8.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/site-packages (from ccy>=1.2.2->-r ./requirements.txt (line 11)) (2020.5)
# Requirement already satisfied: six>=1.10 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from datapackage>=1.15.2->-r ./requirements.txt (line 8)) (1.15.0)
# Requirement already satisfied: jsonschema>=2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from datapackage>=1.15.2->-r ./requirements.txt (line 8)) (3.2.0)
# Collecting tabulator>=1.29
#   Downloading tabulator-1.53.5-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: requests>=2.8 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datapackage>=1.15.2->-r ./requirements.txt (line 8)) (2.25.1)
# Requirement already satisfied: chardet>=3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datapackage>=1.15.2->-r ./requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: click>=6.7 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datapackage>=1.15.2->-r ./requirements.txt (line 8)) (7.1.2)
# Collecting tableschema>=1.12.1
#   Downloading tableschema-1.20.2-py2.py3-none-any.whl (68 kB)
# Collecting unicodecsv>=0.14
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
# Collecting jsonpointer>=1.10
#   Downloading jsonpointer-2.1-py2.py3-none-any.whl (7.4 kB)
# Collecting aiohttp<4.0,>=3.6
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: scipy<2,>=1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataprep>=0.2.15->-r ./requirements.txt (line 10)) (1.6.2)
# Collecting dask[array,dataframe,delayed]<3.0,>=2.25
#   Downloading dask-2.30.0-py3-none-any.whl (848 kB)
# Collecting wordcloud<2.0,>=1.8
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
# Requirement already satisfied: pydantic<2.0,>=1.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataprep>=0.2.15->-r ./requirements.txt (line 10)) (1.7.3)
# Requirement already satisfied: nltk<4.0,>=3.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataprep>=0.2.15->-r ./requirements.txt (line 10)) (3.6.1)
# Requirement already satisfied: tqdm<5.0,>=4.48 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataprep>=0.2.15->-r ./requirements.txt (line 10)) (4.60.0)
# Requirement already satisfied: bokeh<3,>=2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataprep>=0.2.15->-r ./requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: jinja2<3.0,>=2.11 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from dataprep>=0.2.15->-r ./requirements.txt (line 10)) (2.11.3)
# Collecting regex<2021.0.0,>=2020.10.15
#   Downloading regex-2020.11.13-cp37-cp37m-manylinux2014_x86_64.whl (719 kB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Downloading jsonpath_ng-1.5.2-py3-none-any.whl (28 kB)
# Collecting bottleneck<2.0,>=1.3
#   Downloading Bottleneck-1.3.2.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (5.5.3)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Requirement already satisfied: ipython>=4.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (7.22.0)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (5.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.2->-r ./requirements.txt (line 2)) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.2->-r ./requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.2.2->-r ./requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.2.2->-r ./requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.4.4)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (4.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.24->-r ./requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.24->-r ./requirements.txt (line 3)) (1.0.1)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (20.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (3.7.4.3)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
# Requirement already satisfied: PyYAML>=3.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (5.4.1)
# Requirement already satisfied: packaging>=16.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (20.9)
# Requirement already satisfied: tornado>=5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh<3,>=2->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (6.1)
# Collecting cloudpickle>=0.2.2
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: toolz>=0.8.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dask[array,dataframe,delayed]<3.0,>=2.25->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (0.11.1)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-0.9.0-py3-none-any.whl (107 kB)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fsspec>=0.6.0->dask[array,dataframe,delayed]<3.0,>=2.25->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (3.10.1)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (6.1.12)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (3.0.18)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (54.1.2)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.17.2)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2<3.0,>=2.11->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (1.1.1)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (0.17.3)
# Requirement already satisfied: async-generator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (1.10)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (22.0.3)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.2.0)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.8->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.8->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.8->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (2020.12.5)
# Collecting cached-property>=1.5
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting rfc3986>=1.1.0
#   Downloading rfc3986-1.4.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: isodate>=0.5.4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tableschema>=1.12.1->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (0.6.0)
# Collecting linear-tsv>=1.0
#   Downloading linear-tsv-1.1.0.tar.gz (9.6 kB)
# Requirement already satisfied: boto3>=1.9 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tabulator>=1.29->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (1.17.50)
# Collecting ijson>=3.0.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
# Collecting openpyxl>=2.6
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tabulator>=1.29->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (1.3.24)
# Collecting xlrd>=1.0
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting jsonlines>=1.1
#   Downloading jsonlines-2.0.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: botocore<1.21.0,>=1.20.50 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (1.20.50)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (0.3.6)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from boto3>=1.9->tabulator>=1.29->datapackage>=1.15.2->-r ./requirements.txt (line 8)) (0.10.0)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (7.0.0.dev0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.9.4)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (1.14.5)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->-r ./requirements.txt (line 6)) (2.20)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert>=5.6.1->-r ./requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->fsspec>=0.6.0->dask[array,dataframe,delayed]<3.0,>=2.25->dataprep>=0.2.15->-r ./requirements.txt (line 10)) (3.4.1)
# Building wheels for collected packages: pycountry, bottleneck, linear-tsv, unicodecsv, et-xmlfile
#   Building wheel for pycountry (setup.py): started
#   Building wheel for pycountry (setup.py): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746863 sha256=39ae432bb3af885dc457c55d628a1a3748bfd164e509fec1230489774a0df266
#   Stored in directory: /root/.cache/pip/wheels/57/e8/3f/120ccc1ff7541c108bc5d656e2a14c39da0d824653b62284c6
#   Building wheel for bottleneck (PEP 517): started
#   Building wheel for bottleneck (PEP 517): finished with status 'done'
#   Created wheel for bottleneck: filename=Bottleneck-1.3.2-cp37-cp37m-linux_x86_64.whl size=114341 sha256=27a7cb65a19a092464bdac1224c380d28e179373bbcd69951f34428c2de8c61c
#   Stored in directory: /root/.cache/pip/wheels/87/85/9c/a325c89ff0498660ef8a335fb4b3912939c273ea4f094af29f
#   Building wheel for linear-tsv (setup.py): started
#   Building wheel for linear-tsv (setup.py): finished with status 'done'
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7382 sha256=d17c6aa5a060716882d70224f3fc84abaeb1b1a4a045bbf07369134215b17bad
#   Stored in directory: /root/.cache/pip/wheels/dd/0a/62/49ee84fab92057fb3e303fb1a59e75ccac6899b417f441305a
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10767 sha256=3ab1e71f134052a33c4b311778c6f2bf0c450d02221a752d84533b11c3a83c4a
#   Stored in directory: /root/.cache/pip/wheels/1a/f4/8a/a5024fb77b32ed369e5c409081e5f00fbe3b92fdad653f6e69
#   Building wheel for et-xmlfile (setup.py): started
#   Building wheel for et-xmlfile (setup.py): finished with status 'done'
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=28a29d9ae1170be724c09317d793743c4272858bd3b0f20ff11a345f1decb95b
#   Stored in directory: /root/.cache/pip/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
# Successfully built pycountry bottleneck linear-tsv unicodecsv et-xmlfile
# Installing collected packages: et-xmlfile, xlrd, unicodecsv, openpyxl, multidict, locket, linear-tsv, jsonlines, ijson, yarl, widgetsnbextension, tabulator, rfc3986, regex, ply, partd, jupyterlab-widgets, fsspec, dask, cloudpickle, cached-property, async-timeout, wordcloud, tableschema, jsonpointer, jsonpath-ng, ipywidgets, geographiclib, bottleneck, aiohttp, pycountry, geopy, dataprep, datapackage, ccy
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.4.4
#     Not uninstalling regex at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'regex'. No files were found to uninstall.
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 bottleneck-1.3.2 cached-property-1.5.2 ccy-1.2.2 cloudpickle-1.6.0 dask-2.30.0 datapackage-1.15.2 dataprep-0.2.15 et-xmlfile-1.0.1 fsspec-0.9.0 geographiclib-1.50 geopy-2.1.0 ijson-3.1.4 ipywidgets-7.6.3 jsonlines-2.0.0 jsonpath-ng-1.5.2 jsonpointer-2.1 jupyterlab-widgets-1.0.0 linear-tsv-1.1.0 locket-0.2.1 multidict-5.1.0 openpyxl-3.0.7 partd-1.2.0 ply-3.11 pycountry-20.7.3 regex-2020.11.13 rfc3986-1.4.0 tableschema-1.20.2 tabulator-1.53.5 unicodecsv-0.14.1 widgetsnbextension-3.5.1 wordcloud-1.8.1 xlrd-2.0.1 yarl-1.6.3

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6d844b8b-c2b2-41b2-8d9c-38e9bb4a0873' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
